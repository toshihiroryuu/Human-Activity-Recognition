# %%
import urllib
import urllib.request
import json
import time
import numpy as np
from csv import writer
from datetime import datetime
import pandas as pd
import shutil

# %%
head_cols = ['mobileno', 'value']

# %%
url = 'https://api.thingspeak.com/channels/508740/fields/'

# %%
# a = urllib.request.urlopen(url+'2/last.json').read()
# res_dict = json.loads(a.decode('utf-8'))
# res_dict
# Out:
# {'created_at': '2021-06-16T14:48:49Z',
#  'entry_id': 669,
#  'field2': '1457910.73129_3_-1.109_6.752_7.073'}

# %%
def get_data_mobile1(url):
    a = urllib.request.urlopen(url+'1/last.json').read()
    res_dict = json.loads(a.decode('utf-8'))
    
    mobile1_values = res_dict['field1']
    mobile = "mobile1"
    return mobile, mobile1_values

# %%
def get_data_mobile2():
    a = urllib.request.urlopen(url+'2/last.json').read()
    res_dict = json.loads(a.decode('utf-8'))

    mobile2_values = res_dict["field2"]
    mobile = "mobile2"
    return mobile, mobile2_values

# %%
path_dock = '/home/jovyan/work/mldb_proj/data//'

# %%
path_jupy = 'C:/Users/asham/mlspark/mldb_proj//data/'

# %%
i=0
while True:
    time.sleep(5)
    i=i+1
    data1 = get_data_mobile1()
    data2 = get_data_mobile2()
    print("Data 1:",data1)
    print("Data 2:",data2)

    data =[data1, data2]
    df = pd.DataFrame(data,columns=head_cols)
    df.to_csv(path_dock+'test{}.csv'.format(i), index =False)   # for docker spark
  #  df.to_csv(path_jupy+'test{}.csv'.format(i), index =False) # for normal jupyter
# Out:
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# Data 1: ('mobile1', '82670.05203_3_-0.209_8.736_4.685_5_-39.334_-8.984_11.604')
# Data 2: ('mobile2', '1457910.73129_3_-1.109_6.752_7.073')
# ...
